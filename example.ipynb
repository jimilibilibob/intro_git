# %%
import pandas as pd

# %%
! ls
# Out:
# chiffres-cles.csv  example.ipynb  example.txt

# %%
df = pd.read_csv("./chiffres-cles.csv")
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#          date  granularite maille_code         maille_nom  cas_confirmes  \
# 0  2020-01-24  departement      DEP-16           Charente            0.0
# 1  2020-01-24  departement      DEP-17  Charente-Maritime            0.0
# 2  2020-01-24  departement      DEP-19            Corrèze            0.0
# 3  2020-01-24  departement      DEP-23             Creuse            0.0
# 4  2020-01-24  departement      DEP-24           Dordogne            0.0
#
#    cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  deces  deces_ehpad  \
# 0        NaN                  NaN                  NaN    NaN          NaN
# 1        NaN                  NaN                  NaN    NaN          NaN
# 2        NaN                  NaN                  NaN    NaN          NaN
# 3        NaN                  NaN                  NaN    NaN          NaN
# 4        NaN                  NaN                  NaN    NaN          NaN
#
#    reanimation  hospitalises  nouvelles_hospitalisations  \
# ...

# %%
df.describe()
# Out:
#        cas_confirmes     cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  \
# count   3.003000e+03     49.000000           235.000000            15.000000
# mean    4.956855e+04  68314.959184         47699.021277         35228.000000
# std     2.442747e+05   9760.158846         22298.228077          5673.218474
# min     0.000000e+00  37188.000000         11958.000000         25230.000000
# 25%     5.000000e+00  67168.000000         37599.000000         32238.500000
# 50%     2.500000e+01  72548.000000         39645.000000         37379.000000
# 75%     1.830000e+02  74402.000000         46110.500000         38896.500000
# max     2.292497e+06  74516.000000        119716.000000         40726.000000
#
#               deces   deces_ehpad   reanimation  hospitalises  \
# count  33568.000000    249.000000  32385.000000  32467.000000
# mean     617.376400  10535.590361     71.814544    487.176672
# std     2679.836483   2552.710174    386.515534   2361.208457
# ...

# %%
df_dpt = df[df["granularite"]=="departement"]
df_dpt.head()
# Out:
#          date  granularite maille_code         maille_nom  cas_confirmes  \
# 0  2020-01-24  departement      DEP-16           Charente            0.0
# 1  2020-01-24  departement      DEP-17  Charente-Maritime            0.0
# 2  2020-01-24  departement      DEP-19            Corrèze            0.0
# 3  2020-01-24  departement      DEP-23             Creuse            0.0
# 4  2020-01-24  departement      DEP-24           Dordogne            0.0
#
#    cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  deces  deces_ehpad  \
# 0        NaN                  NaN                  NaN    NaN          NaN
# 1        NaN                  NaN                  NaN    NaN          NaN
# 2        NaN                  NaN                  NaN    NaN          NaN
# 3        NaN                  NaN                  NaN    NaN          NaN
# 4        NaN                  NaN                  NaN    NaN          NaN
#
#    reanimation  hospitalises  nouvelles_hospitalisations  \
# ...

# %%
df_dpt.describe()
# Out:
#        cas_confirmes  cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  \
# count    1649.000000        0.0                  0.0                  0.0
# mean       38.085506        NaN                  NaN                  NaN
# std        76.077147        NaN                  NaN                  NaN
# min         0.000000        NaN                  NaN                  NaN
# 25%         3.000000        NaN                  NaN                  NaN
# 50%        10.000000        NaN                  NaN                  NaN
# 75%        39.000000        NaN                  NaN                  NaN
# max       827.000000        NaN                  NaN                  NaN
#
#               deces  deces_ehpad   reanimation  hospitalises  \
# count  27825.000000          0.0  26908.000000  26971.000000
# mean     184.652543          NaN     21.443920    146.752623
# std      302.020322          NaN     48.559604    271.530766
# ...
